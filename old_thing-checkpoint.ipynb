# %%
import wraplorenzmie.utilities.utilities as utilities
import wraplorenzmie.fits.fit as fit
import imageio
# For Plotting.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#sns.set(style='white', font_scale=2)
# %matplotlib inline
import matplotlib as mpl


mpl.rcParams["figure.dpi"] = 130
from matplotlib import rc
rc('font', family='serif')
rc('text', usetex=True)
rc('xtick', labelsize='x-small')
rc('ytick', labelsize='x-small')

def cm2inch(value):
    return value/2.54

calib = 0.0532 #um/px
# Out:
# No module named 'pylorenzmie.fitting.cython.cminimizers'

# %%
import os
import subprocess

# %%
filename = "12_sphere7_F4_fps100_expo1000_Basler_acA1920-155um__22392621__20220113_151700948.mp4"
#filename_trimmed = "Basler_acA1920-155um__22392621__20211130_173844381_trimmed.mp4"

#from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
#ffmpeg_extract_subclip(filename, 29*60, 64*60, targetname=filename_trimmed)

experiment="12_sphere7_F4_fps100_expo1000"
date = "13012022"
particle = "diffuse_TEST"

generic_output_name = "_"+experiment+"_"+date+"_"+particle
print(generic_output_name)
# Out:
# _12_sphere7_F4_fps100_expo1000_13012022_diffuse_TEST

# %%
#%%javascript
#Jupyter.notebook.rename("traitement"+generic_output_name+".ipynb")

# %%
vid = utilities.video_reader(filename)
cmd = r"ffprobe -v error -select_streams v:0 -count_packets -show_entries stream=nb_read_packets -of csv=p=0 " + filename
nb_image = int(subprocess.check_output(cmd, shell=True))
nb_image
# Out:
# 7858

# %%
def radial_profile(data, center=None):
    if center==None:
        center = np.array(np.shape(data)) / 2
    
    y, x = np.indices((data.shape))
    r = np.sqrt((x - center[0])**2 + (y - center[1])**2)
    r = r.astype(np.int)

    tbin = np.bincount(r.ravel(), data.ravel())
    nr = np.bincount(r.ravel())
    radialprofile = tbin / nr
    
    T = data.ravel()
    V = r.ravel()
    
    err = [np.std(T[V == u]) for u in np.unique(V)]
    
    return radialprofile, err

# %%
image = vid.get_image(1)
plt.imshow(image,cmap="gray")

# %%
vid.number = 6000
#vid.background = np.array(imageio.imread("background.tiff"))
#background = vid.get_background(30)
background = np.ones_like(image)* np.mean(image)
vid.background = background
plt.imshow(vid.background,cmap="gray")
print(np.mean(image))
# Out:
# 23.577099444444446

# %%
#imageio.imwrite("background_09122021.tiff",vid.background)
imageio.imwrite("background"+generic_output_name+".tiff", vid.background)

# %%
normed_image = utilities.normalize(image, vid.background)
plt.imshow(normed_image, cmap="gray")
normed_image = normed_image

# %%
feature, circ = utilities.center_find(image)
feature
# Out:
# array([[ 847.84769116,  140.89889523,  400.        ,  400.        ],
#        [ 710.03206154,  147.95910992,  400.        ,  400.        ],
#        [ 714.43665385,  245.47621556,  400.        ,  400.        ],
#        [ 735.42715235,  577.12569447,  400.        ,  400.        ],
#        [ 621.26649588,  716.29873742,  400.        ,  400.        ],
#        [ 621.09779841,  926.59817283,  400.        ,  400.        ],
#        [  99.06136634, 1038.13761506,  400.        ,  400.        ],
#        [ 236.96627016, 1083.92097116,  400.        ,  400.        ],
#        [ 692.5186799 , 1140.58166523,  400.        ,  400.        ]])

# %%
feature = np.array([feature[3]])
feature
# Out:
# array([[735.42715235, 577.12569447, 400.        , 400.        ]])

# %%
utilities.plot_bounding(normed_image,feature)

# %%
x, y, w, h = feature[0]
x = x + 10
y = y - 2
x_center = x
y_center = y
h = 130
im_c = fit.crop(image, int(x), int(y), int(h))
bk_c = fit.crop(vid.background, int(x), int(y), int(h))
cropped = utilities.normalize(im_c,bk_c, dark_count = np.min(im_c))
cropped = cropped / np.mean(cropped)
plt.imshow(cropped,cmap = "gray")

# %%
fitter = fit.fitting(cropped,0.532,calib, n_m = 1.33)
fitter.make_guess(1.5,1.59,8,alpha = 1,fit_r=True, fit_n=True,fit_alpha=True)

# %%
#%timeit result = fitter.fit_single(cropped, method = "lm")
result = fitter.fit_single(cropped, method = "lm")

# %%
zo = result.result["x"][2] * calib
print(result.result["x"][2]*calib)
print(result.redchi)
print(result.result["x"])
# Out:
# 8.49469105414496
# 20.658559706190932
# [ 63.67250743  64.96432016 159.67464387   1.50479127   1.58997086
#    1.0080925 ]

# %%
result.result.x
# Out:
# array([ 63.67250743,  64.96432016, 159.67464387,   1.50479127,
#          1.58997086,   1.0080925 ])

# %%
result.result
# Out:
#  active_mask: array([0, 0, 0, 0, 0, 0])
#         cost: 17394.507272612766
#          fun: array([ 2.21622251,  0.10560335, -1.64574496, ..., -2.93837343,
#        -0.52070769, -3.19050814])
#         grad: array([-2.03313459e+01, -1.19518130e+00, -1.98687088e+00,  2.85090836e+03,
#        -2.54445383e+03, -7.08256501e+01])
#          jac: array([[ 2.43634159e+00, -9.31381882e-01, -3.46400923e-01,
#          7.06901172e+01,  2.32557225e+02,  1.04789777e+01],
#        [-2.35047945e+00, -7.84813707e-01,  1.60881991e-01,
#         -8.31903100e+01, -3.70069352e+02,  1.44011114e+01],
#        [-8.46035202e-02, -1.17982949e+00, -1.26733545e-01,
#          2.99401881e+01,  6.33235549e+01,  1.70086472e+01],
#        ...,
#        [-1.06492366e-01, -1.11609700e-01,  9.44047849e-02,
#         -2.66890147e+00, -1.46608483e+01,  1.64715150e+01],
#        [ 8.12352768e-01,  2.41506404e+00, -3.29323190e-01,
#          7.06977446e+01,  2.39877440e+02,  9.10380190e+00],
#        [ 8.39804159e-02,  6.12938533e-02,  1.13809779e-01,
#         -4.64414079e+01, -1.05410794e+02,  4.63818654e+01]])
#      message: '`ftol` termination condition is satisfied.'
#         nfev: 60
#         njev: None
#   optimality: 2850.908356021055
#       status: 2
#      success: True
#            x: array([ 63.67250743,  64.96432016, 159.67464387,   1.50479127,
#          1.58997086,   1.0080925 ])

# %%
np.linalg.inv(np.dot(np.transpose(result.result.jac), result.result.jac))
# Out:
# array([[ 1.83731594e-04, -3.36675498e-06, -1.65825338e-05,
#         -2.43727161e-07,  1.83536208e-08,  1.00930445e-07],
#        [-3.36675498e-06,  1.88716473e-04,  7.96561138e-05,
#          1.18866797e-07,  1.24139013e-07, -2.00427926e-07],
#        [-1.65825338e-05,  7.96561138e-05,  1.65015552e-02,
#          1.99461753e-04, -2.96126202e-05,  1.81166117e-05],
#        [-2.43727161e-07,  1.18866797e-07,  1.99461753e-04,
#          4.05321859e-06, -9.11796597e-07,  2.30612352e-07],
#        [ 1.83536208e-08,  1.24139013e-07, -2.96126202e-05,
#         -9.11796597e-07,  2.55326281e-07, -3.31781184e-08],
#        [ 1.00930445e-07, -2.00427926e-07,  1.81166117e-05,
#          2.30612352e-07, -3.31781184e-08,  4.08961409e-07]])

# %%
np.shape(result.result.fun)
# Out:
# (1690,)

# %%
np.shape(fitter.image.flatten())
# Out:
# (16900,)

# %%
fitter.show_results()

# %%
center = np.array(np.shape(fitter.image))

# %%
radial_exp, err = radial_profile(fitter.image)
# Out:
# /tmp/ipykernel_18933/1905413837.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   r = r.astype(np.int)

# %%
np.shape(radial_exp)
# Out:
# (92,)

# %%
radial_exp, err = radial_profile(fitter.image)
theo_exp, err = radial_profile(fitter.fitter.model.hologram().reshape(fitter.shape))

radius_radial = np.arange(len(radial_exp))
plt.plot(radius_radial, radial_exp, label="Experimental")
plt.fill_between(radius_radial, radial_exp - err, radial_exp + err, alpha = 0.3)
plt.plot(radius_radial, theo_exp, label="Theory")
plt.legend()
plt.xlabel("radius [pixel]")
plt.ylabel("Intensity [a.u.]")
#plt.figure(figsize=(cm2inch(8.6),1.65*cm2inch(8.6)))
# Out:
# /tmp/ipykernel_18933/1905413837.py:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   r = r.astype(np.int)
# Text(0, 0.5, 'Intensity [a.u.]')

# %%
sigma = np.sum((fitter.image - fitter.fitter.model.hologram().reshape(fitter.shape)) ** 2)
H_1 = np.linalg.inv(np.dot(np.transpose(result.result.jac), result.result.jac))

error = 1.96 * np.sqrt(sigma * np.diag(H_1)) * [0.0513,0.0513,0.0513,1,1,1]

# %%
error
# Out:
# array([0.04377996, 0.04436989, 0.41490231, 0.12675528, 0.03181367,
#        0.0402631 ])

# %%
radius_radial = radius_radial * calib

# %%
fit_data = {}


fig = plt.figure(figsize=(cm2inch(8.6),1.65*cm2inch(8.6)))
fig.subplots_adjust(left=0.14, bottom=.12, right=.99, top=.98)

plt.subplot(2,2,1)
plt.imshow(fitter.image, cmap = "gray")
#plt.title('subplot(2,2,1)')

fit_data["exp_image"] = fitter.image

plt.subplot(2,2,2)
plt.imshow(fitter.fitter.model.hologram().reshape(fitter.shape), cmap = "gray")
frame1 = plt.gca()
frame1.axes.yaxis.set_ticklabels([])

fit_data["th_image"] = fitter.fitter.model.hologram().reshape(fitter.shape)


#plt.title('subplot(2,2,2)')

plt.subplot(2,2,(3,4))
plt.plot(radius_radial, radial_exp, label="Expérience", linewidth=1.2)
plt.fill_between(radius_radial, radial_exp - err, radial_exp + err, alpha = 0.3)
plt.plot(radius_radial, theo_exp, label="Théorie", linewidth=1.0, ls='--')
plt.legend(frameon=False)
plt.xlabel("Distance radiale $(\mathrm{\mu m})$")
plt.ylabel("$I/I_0$")

fit_data["I_r_exp"] = radial_exp
fit_data["I_errr_exp"] = err

fit_data["theo_exp"] = theo_exp
fit_data["I_radius"] = radius_radial

fig.set_size_inches(cm2inch(8.6), cm2inch(1.6 * 8.6/1.618))

plt.tight_layout()

plt.savefig("fit_first_im"+generic_output_name+".svg")

# %%
from scipy.io import savemat
savemat("data_fit_first_im"+generic_output_name+".mat", fit_data)

# %%
fitter.fit_video(vid = vid,savefile="find_nr"+generic_output_name+".dat",xc = x ,yc= y, h=130, n_end=5000, method = "lm", dark_count_mode="min")
# Out:
# 100%|███████████████████████████████████████| 4999/4999 [02:30<00:00, 33.22it/s]

# %%
n_r = np.fromfile("find_nr"+generic_output_name+".dat", dtype=np.float64)
n_r = n_r.reshape(len(n_r)//10,10)
r = n_r[:,3]
n = n_r[:,4]

# %%
plt.plot(r)

# %%
sns.distplot(r)
# Out:
# /home/brownianxgames/miniconda3/envs/pylorenzmie/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
np.mean(n)
# Out:
# 1.601530834890248

# %%
H, xedges, yedges = np.histogram2d(n, r, bins=100)
H = H.T  # Let each row list bins with common y range.


plt.hist2d(r,n, bins = 150)
plt.ylabel("n")
plt.xlabel("r [$\mathrm{\mu m}$]")
# Out:
# Text(0.5, 0, 'r [$\\mathrm{\\mu m}$]')

# %%
data = np.random.multivariate_normal((0, 0), [[0.8, 0.05], [0.05, 0.7]], 100)

# %%
import numpy as np
import matplotlib.pyplot as pl
import scipy.stats as st

data = np.random.multivariate_normal((0, 0), [[0.8, 0.05], [0.05, 0.7]], 100)
x = r[(r>1.48) & (r<1.55)]
y = n[(r>1.48) & (r<1.55)]
xmin, xmax = np.min(x), np.max(x)
ymin, ymax = np.min(y), np.max(y)

# Peform the kernel density estimate
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([x, y])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
f = f/np.max(f)

fig = plt.figure()
ax = fig.gca()
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
# Contourf plot
cfset = ax.contourf(xx, yy, f, cmap='Blues')
## Or kernel density estimate plot instead of the contourf plot
#ax.imshow(np.rot90(f), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
# Contour plot
cset = ax.contour(xx, yy, f, colors='k', levels=6)
# Label plot
ax.clabel(cset, inline=1, fontsize=8, fmt="%1.1f")
plt.scatter(xx[np.where(f == 1)],yy[np.where(f == 1)], color = "red", marker="+")
ax.set_xlabel("r [$\mathrm{\mu m}$]")
ax.set_ylabel("n")
plt.title("KDE r n")

#pl.show()
# Out:
# Text(0.5, 1.0, 'KDE r n')

# %%
xx[np.where(f == 1)],yy[np.where(f == 1)]
# Out:
# (array([1.51228851]), array([1.58721869]))

# %%
print(" n determined with : mu={0}, sigma={1}".format(np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])))
print(" r determined with : mu={0}, sigma={1}".format(np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])))

mu_n, sigma_n = np.mean(yy[np.where(f > 0.2)]), np.std(yy[np.where(f > 0.2)])
mu_r, sigma_r = np.mean(xx[np.where(f > 0.2)]), np.std(xx[np.where(f > 0.2)])
mu_n = np.mean(n)
mu_r
# Out:
#  n determined with : mu=1.5867352446770995, sigma=0.0035112146144735557
#  r determined with : mu=1.5164098844302638, sigma=0.005949841113917108
# 1.5164098844302638

# %%
import warnings
warnings.filterwarnings('ignore')
#del fitter
fitter = fit.fitting(cropped,0.532, calib, n_m = 1.33)
fitter.make_guess(mu_r,mu_n,zo,alpha = 1,fit_r=False, fit_n=False,fit_alpha=False)
#result = fitter.fit_single(cropped, method = "lm")
fitter.fit_video(vid = vid,savefile="traj"+generic_output_name+".dat",xc = x_center ,yc= y_center, h = 130, n_end=vid.number,method = "lm")
# Out:
# 100%|███████████████████████████████████████| 5999/5999 [01:30<00:00, 66.16it/s]

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.fromfile("traj"+generic_output_name+".dat", dtype=np.float64)
data = data.reshape(len(data)//10,10)
#data = data[:115000,:]
x = data[:,0] * calib
y = data[:,1] * calib
z = data[:,2] * calib

# %%
import numpy as np
import scipy.io as sio

# %%
radiusstr = "_rp" + str(round(mu_r,4))
indexstr = "_np" + str(round(mu_n,4))
radiusstr = radiusstr.replace('.','p')
indexstr = indexstr.replace('.','p')

sio.savemat("fit_result_rigid"+generic_output_name+radiusstr+indexstr+".mat", {'data':data})

# %%
plt.plot(x, label='x')
plt.plot(y, label='y')
plt.legend()

# %%
plt.plot(z[:
          ])

# %%
np.shape(data)
# Out:
# (257999, 10)

# %%
data
# Out:
# array([[5.51858284e+02, 4.40009602e+02, 1.33812175e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00],
#        [5.51345152e+02, 4.38133145e+02, 1.33479125e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00],
#        [5.51147207e+02, 4.38046031e+02, 1.33332992e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00],
#        ...,
#        [5.43812894e+02, 5.23287781e+02, 1.22360693e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00],
#        [5.42311661e+02, 5.23482229e+02, 1.23131913e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00],
#        [5.41079767e+02, 5.23611542e+02, 1.22415098e+02, ...,
#         5.32000000e-01, 5.32000000e-02, 1.00000000e+00]])
